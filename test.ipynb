# %%
import py_api_connector

# %%
g = py_api_connector.compress("/home/exouser/amr_dumpi_files/event_graph.graphml", 3, 8)
# Out:
# Loaded attributes...
# Created MPI encoding...
# Initialized compressed node map...
# Initialized process to node map...
# Populated for process #0
# Populated for process #2
# Populated for process #1
# Populated for process #Populated for process #3
# Populated for process #Populated for process #65
# Populated for process #7
#
# 4
# Initializing isend_seq...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Adjusted node labels...
# Created edges for process #5
# Created edges for process #2
# Created edges for process #6
# Created edges for process #1
# Created edges for process #4
# Created edges for process #7
# Created edges for process #3
# Created edges for process #0
# Loaded attributes...
# MPI functions enumerated...
# Alltoall communication nodes isolated...
# Subgraph identity map initialized...
# Subgraph extracted...
# ...
