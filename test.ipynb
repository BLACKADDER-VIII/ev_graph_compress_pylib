# %%
import py_api_connector
# Out:
# /home/exouser/Enzo-ND/Enzo_ND_Detect/submodules/ev_graph_compress_pylib/py_api_connector.py:6: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(c_lvl>0 and c_lvl<=3, "c_lvl needs to be between 1 and 3")
# /home/exouser/Enzo-ND/Enzo_ND_Detect/submodules/ev_graph_compress_pylib/py_api_connector.py:7: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(num_proc>0, "num_proc needs to be more than 0")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import py_api_connector
#
# File ~/Enzo-ND/Enzo_ND_Detect/submodules/ev_graph_compress_pylib/py_api_connector.py:2
#       1 import sys; sys.path.append("build")
# ----> 2 import nd_compress
#       3 import igraph as ig
#       5 def compress(graph_path, c_lvl, num_proc):
#
# ModuleNotFoundError: No module named 'nd_compress'
